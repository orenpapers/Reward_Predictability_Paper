# %%
import pandas as pd
import datetime
print(datetime.datetime.now())
a = pd.read_csv("/Users/orenkobo/Desktop/PhD/Aim2_new/Analysis_artifacts/new_proc_FINAL/null_distributions/null_distribution_distances_df_wholebrain_1000_shuffleX.csv", index_col=False)
print(datetime.datetime.now())
a
# Out:
# 2022-07-27 11:21:22.112577
# 2022-07-27 12:12:38.180984
#             0         1         2         3         4         5         6  \
# 0    5.927681  6.136224  6.489448  6.056669  6.486900  5.756712  6.190002
# 1    6.598710  6.742563  6.875597  6.660099  6.960845  5.983596  6.493953
# 2    6.218593  6.405398  6.746585  6.394486  6.795970  6.077279  6.471653
# 3    5.735664  6.048438  6.386264  5.871477  6.248722  5.719561  5.940665
# 4    6.338383  6.414875  6.570114  6.515459  6.748193  6.324711  6.659651
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  6.279676  6.286636  6.505888  6.562065  6.656723  6.491881  6.730131
# 996  6.094624  6.298722  6.390610  6.192791  6.579768  5.757183  6.245292
# 997  6.046928  6.326842  6.564376  6.208253  6.553989  5.936215  6.371873
# 998  6.145660  6.389161  6.620253  6.236489  6.610939  5.951890  6.244095
# 999  5.800391  6.260011  6.731680  5.981823  6.479281  5.754602  6.149003
#
# ...

# %%
a.to_feather("/Users/orenkobo/Desktop/PhD/Aim2_new/Analysis_artifacts/new_proc_FINAL/null_distributions/null_distribution_distances_df_wholebrain_1000_shuffleX.fthr")

# %%
import joblib
joblib.load("/Users/orenkobo/Desktop/PhD/Aim2_new/Analysis_artifacts/new_proc_FINAL/120422_Newalignment_dict_pre-reg-analyses__WB/1658902508__wholebrain_fdr_i_adjusted_p_list.jbl")
# Out:
# [0.30151926563441517,
#  0.19628232469264176,
#  0.05575035146303642,
#  0.08674917223886837,
#  0.04214713219976858,
#  0.006294963421725563,
#  0.07046749302650412,
#  0.06621721217327749,
#  0.08542673365453454,
#  0.9999999993838622,
#  0.9999999993838622,
#  0.9455045158909787,
#  0.01908490523786609,
#  7.520848235260209e-05,
#  0.0008372311863611378,
#  0.012827340498961422,
#  0.9999999993838622,
#  0.9999999993838622,
#  0.9999999993838622,
#  0.22449126413423975,
#  0.0027250664780050986,
#  6.322919882302558e-05,
#  0.00016052598673761586,
#  0.0006374932760186462,
#  0.0018191956374645107,
#  0.9999999993838622,
#  0.9999999993838622,
#  0.9999999993838622,
#  0.5005816552784536,
#  0.011575003220233082,
#  0.00012183481073996182,
#  2.896114602104093e-05,
#  3.7424750615383095e-05,
#  4.5690896402307374e-05,
#  0.00039118130074289656,
#  0.010672660995105391,
#  0.07625641023162827,
#  0.9999999993838622,
#  0.9999999993838622,
#  0.9999999993838622,
# ...
