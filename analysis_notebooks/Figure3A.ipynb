# %%
import pandas as pd
from ast import literal_eval

res_df = pd.read_csv(r"C:\Users\orenk\Desktop\Aim2_Resources/scc_res_df.csv",
    converters={"per_fold_score": literal_eval})
res_df
# Out:
#     model_type   agg_dim  conf                    fs  \
# 0       actual  temporal     0     SelectKBest(k=13)
# 1        dummy  temporal     0     SelectKBest(k=13)
# 2       actual  temporal     1     SelectKBest(k=13)
# 3        dummy  temporal     1     SelectKBest(k=13)
# 4       actual  temporal     2     SelectKBest(k=13)
# ..         ...       ...   ...                   ...
# 195      dummy  temporal    47  PCA(n_components=24)
# 196     actual  temporal    48  PCA(n_components=24)
# 197      dummy  temporal    48  PCA(n_components=24)
# 198     actual  temporal    49  PCA(n_components=24)
# 199      dummy  temporal    49  PCA(n_components=24)
#
#                                           est       res       c   pval  \
# 0     RandomForestClassifier(n_estimators=50)  0.718833  reward  0.012
# 1     RandomForestClassifier(n_estimators=50)  0.497046  reward    NaN
# 2                    RandomForestClassifier()  0.721667  reward  0.010
# 3                    RandomForestClassifier()  0.500107  reward    NaN
# 4    RandomForestClassifier(n_estimators=200)  0.729500  reward  0.003
# ..                                        ...       ...     ...    ...
# 195         LogisticRegression(max_iter=1000)  0.501850  vision    NaN
# 196  LogisticRegression(C=0.2, max_iter=1000)  0.658083  vision  0.061
# 197  LogisticRegression(C=0.2, max_iter=1000)  0.501732  vision    NaN
# 198  LogisticRegression(C=0.8, max_iter=1000)  0.661333  vision  0.058
# 199  LogisticRegression(C=0.8, max_iter=1000)  0.501425  vision    NaN
#
#                                         per_fold_score
# 0    [0.8333333333333334, 0.6666666666666666, 0.833...
# 1    [0.5785714285714285, 0.525, 0.5857142857142857...
# 2    [0.8333333333333334, 0.6666666666666666, 0.666...
# 3    [0.525, 0.33214285714285713, 0.553571428571428...
# 4    [0.9166666666666666, 0.6666666666666666, 0.75,...
# ..                                                 ...
# 195  [0.4214285714285714, 0.43928571428571433, 0.55...
# 196  [0.5833333333333334, 0.5833333333333334, 0.583...
# 197  [0.4214285714285714, 0.43928571428571433, 0.55...
# 198  [0.5833333333333334, 0.6666666666666666, 0.583...
# 199  [0.4214285714285714, 0.43928571428571433, 0.55...
#
# [200 rows x 9 columns]

# %%
import random
res_df["per_fold_score_balanced"] = [random.sample(x,1000) for x in res_df["per_fold_score"]]
res_df
# Out:
#     model_type   agg_dim  conf                    fs  \
# 0       actual  temporal     0     SelectKBest(k=13)
# 1        dummy  temporal     0     SelectKBest(k=13)
# 2       actual  temporal     1     SelectKBest(k=13)
# 3        dummy  temporal     1     SelectKBest(k=13)
# 4       actual  temporal     2     SelectKBest(k=13)
# ..         ...       ...   ...                   ...
# 195      dummy  temporal    47  PCA(n_components=24)
# 196     actual  temporal    48  PCA(n_components=24)
# 197      dummy  temporal    48  PCA(n_components=24)
# 198     actual  temporal    49  PCA(n_components=24)
# 199      dummy  temporal    49  PCA(n_components=24)
#
#                                           est       res       c   pval  \
# 0     RandomForestClassifier(n_estimators=50)  0.718833  reward  0.012
# 1     RandomForestClassifier(n_estimators=50)  0.497046  reward    NaN
# 2                    RandomForestClassifier()  0.721667  reward  0.010
# 3                    RandomForestClassifier()  0.500107  reward    NaN
# 4    RandomForestClassifier(n_estimators=200)  0.729500  reward  0.003
# ..                                        ...       ...     ...    ...
# 195         LogisticRegression(max_iter=1000)  0.501850  vision    NaN
# 196  LogisticRegression(C=0.2, max_iter=1000)  0.658083  vision  0.061
# 197  LogisticRegression(C=0.2, max_iter=1000)  0.501732  vision    NaN
# 198  LogisticRegression(C=0.8, max_iter=1000)  0.661333  vision  0.058
# 199  LogisticRegression(C=0.8, max_iter=1000)  0.501425  vision    NaN
#
#                                         per_fold_score  \
# 0    [0.8333333333333334, 0.6666666666666666, 0.833...
# 1    [0.5785714285714285, 0.525, 0.5857142857142857...
# 2    [0.8333333333333334, 0.6666666666666666, 0.666...
# 3    [0.525, 0.33214285714285713, 0.553571428571428...
# 4    [0.9166666666666666, 0.6666666666666666, 0.75,...
# ..                                                 ...
# 195  [0.4214285714285714, 0.43928571428571433, 0.55...
# 196  [0.5833333333333334, 0.5833333333333334, 0.583...
# 197  [0.4214285714285714, 0.43928571428571433, 0.55...
# 198  [0.5833333333333334, 0.6666666666666666, 0.583...
# 199  [0.4214285714285714, 0.43928571428571433, 0.55...
#
#                                per_fold_score_balanced
# 0    [0.75, 0.6666666666666666, 0.5833333333333334,...
# 1    [0.33571428571428574, 0.45, 0.4214285714285714...
# 2    [0.5833333333333334, 0.8333333333333334, 0.666...
# 3    [0.5821428571428571, 0.7535714285714287, 0.614...
# 4    [0.5833333333333334, 0.8333333333333334, 0.75,...
# ..                                                 ...
# 195  [0.4214285714285714, 0.5071428571428571, 0.582...
# 196  [0.75, 0.6666666666666666, 0.5833333333333334,...
# 197  [0.24642857142857144, 0.45, 0.2999999999999999...
# 198  [0.5833333333333334, 0.75, 0.6666666666666666,...
# 199  [0.6642857142857143, 0.5571428571428572, 0.467...
#
# [200 rows x 10 columns]

# %%
res_df = res_df.explode('per_fold_score_balanced').rename({"per_fold_score_balanced" : "fold_acc",
                                                           "model_type" : "iter_type"}, axis=1)
res_df
# Out:
#     iter_type   agg_dim  conf                    fs  \
# 0      actual  temporal     0     SelectKBest(k=13)
# 0      actual  temporal     0     SelectKBest(k=13)
# 0      actual  temporal     0     SelectKBest(k=13)
# 0      actual  temporal     0     SelectKBest(k=13)
# 0      actual  temporal     0     SelectKBest(k=13)
# ..        ...       ...   ...                   ...
# 199     dummy  temporal    49  PCA(n_components=24)
# 199     dummy  temporal    49  PCA(n_components=24)
# 199     dummy  temporal    49  PCA(n_components=24)
# 199     dummy  temporal    49  PCA(n_components=24)
# 199     dummy  temporal    49  PCA(n_components=24)
#
#                                           est       res       c   pval  \
# 0     RandomForestClassifier(n_estimators=50)  0.718833  reward  0.012
# 0     RandomForestClassifier(n_estimators=50)  0.718833  reward  0.012
# 0     RandomForestClassifier(n_estimators=50)  0.718833  reward  0.012
# 0     RandomForestClassifier(n_estimators=50)  0.718833  reward  0.012
# 0     RandomForestClassifier(n_estimators=50)  0.718833  reward  0.012
# ..                                        ...       ...     ...    ...
# 199  LogisticRegression(C=0.8, max_iter=1000)  0.501425  vision    NaN
# 199  LogisticRegression(C=0.8, max_iter=1000)  0.501425  vision    NaN
# 199  LogisticRegression(C=0.8, max_iter=1000)  0.501425  vision    NaN
# 199  LogisticRegression(C=0.8, max_iter=1000)  0.501425  vision    NaN
# 199  LogisticRegression(C=0.8, max_iter=1000)  0.501425  vision    NaN
#
#                                         per_fold_score  fold_acc
# 0    [0.8333333333333334, 0.6666666666666666, 0.833...      0.75
# 0    [0.8333333333333334, 0.6666666666666666, 0.833...  0.666667
# 0    [0.8333333333333334, 0.6666666666666666, 0.833...  0.583333
# 0    [0.8333333333333334, 0.6666666666666666, 0.833...      0.75
# 0    [0.8333333333333334, 0.6666666666666666, 0.833...      0.75
# ..                                                 ...       ...
# 199  [0.4214285714285714, 0.43928571428571433, 0.55...  0.557143
# 199  [0.4214285714285714, 0.43928571428571433, 0.55...  0.442857
# 199  [0.4214285714285714, 0.43928571428571433, 0.55...  0.585714
# 199  [0.4214285714285714, 0.43928571428571433, 0.55...     0.525
# 199  [0.4214285714285714, 0.43928571428571433, 0.55...  0.360714
#
# [200000 rows x 10 columns]

# %%
df_to_viz = res_df[res_df.agg_dim == 'temporal'].rename({"c" : "roi"}, axis=1) #Shape of x is 36 (n_subjects) * 12031 (n_voxels) for spatial and 36X269 for temporal
df_to_viz
# Out:
#     iter_type   agg_dim  conf                    fs  \
# 0      actual  temporal     0     SelectKBest(k=13)
# 0      actual  temporal     0     SelectKBest(k=13)
# 0      actual  temporal     0     SelectKBest(k=13)
# 0      actual  temporal     0     SelectKBest(k=13)
# 0      actual  temporal     0     SelectKBest(k=13)
# ..        ...       ...   ...                   ...
# 199     dummy  temporal    49  PCA(n_components=24)
# 199     dummy  temporal    49  PCA(n_components=24)
# 199     dummy  temporal    49  PCA(n_components=24)
# 199     dummy  temporal    49  PCA(n_components=24)
# 199     dummy  temporal    49  PCA(n_components=24)
#
#                                           est       res     roi   pval  \
# 0     RandomForestClassifier(n_estimators=50)  0.718833  reward  0.012
# 0     RandomForestClassifier(n_estimators=50)  0.718833  reward  0.012
# 0     RandomForestClassifier(n_estimators=50)  0.718833  reward  0.012
# 0     RandomForestClassifier(n_estimators=50)  0.718833  reward  0.012
# 0     RandomForestClassifier(n_estimators=50)  0.718833  reward  0.012
# ..                                        ...       ...     ...    ...
# 199  LogisticRegression(C=0.8, max_iter=1000)  0.501425  vision    NaN
# 199  LogisticRegression(C=0.8, max_iter=1000)  0.501425  vision    NaN
# 199  LogisticRegression(C=0.8, max_iter=1000)  0.501425  vision    NaN
# 199  LogisticRegression(C=0.8, max_iter=1000)  0.501425  vision    NaN
# 199  LogisticRegression(C=0.8, max_iter=1000)  0.501425  vision    NaN
#
#                                         per_fold_score  fold_acc
# 0    [0.8333333333333334, 0.6666666666666666, 0.833...      0.75
# 0    [0.8333333333333334, 0.6666666666666666, 0.833...  0.666667
# 0    [0.8333333333333334, 0.6666666666666666, 0.833...  0.583333
# 0    [0.8333333333333334, 0.6666666666666666, 0.833...      0.75
# 0    [0.8333333333333334, 0.6666666666666666, 0.833...      0.75
# ..                                                 ...       ...
# 199  [0.4214285714285714, 0.43928571428571433, 0.55...  0.557143
# 199  [0.4214285714285714, 0.43928571428571433, 0.55...  0.442857
# 199  [0.4214285714285714, 0.43928571428571433, 0.55...  0.585714
# 199  [0.4214285714285714, 0.43928571428571433, 0.55...     0.525
# 199  [0.4214285714285714, 0.43928571428571433, 0.55...  0.360714
#
# [200000 rows x 10 columns]

# %%
from shared_analysis_utils import strip_fs, strip_est

# %%
df_to_viz["fs"] = strip_fs(df_to_viz["fs"])
df_to_viz["est"] = strip_est(df_to_viz["est"])

# %%
import seaborn as sns
df_to_viz = df_to_viz[(df_to_viz.fs == "PCA(20)") & (df_to_viz.est == "SVC('linear')")].reset_index(drop=True)
sns.boxplot(data = df_to_viz , x="roi", hue='iter_type', y='fold_acc')
# Out:
# <AxesSubplot: xlabel='roi', ylabel='fold_acc'>

# %%
from shared_analysis_utils import draw_stars_box
import matplotlib.pyplot as plt
ir = 0
for roi, df_chosen_roi in df_to_viz.groupby(["roi"]):
    fig, axs = plt.subplots(1, 2, figsize=(12,4))
    if ir == 0:
        fig.suptitle(f"Subject classification accuracy", fontsize = 16)
    null_dist = df_chosen_roi[df_chosen_roi.iter_type=='dummy'].fold_acc
    actual_dist = df_chosen_roi[df_chosen_roi.iter_type=='actual'].fold_acc
    actual_error = actual_dist.mean()

    sns.histplot(null_dist,  bins=50, ax = axs[0])
    axs[0].axvline(x=actual_error, color='green')
    axs[0].text(0.25, 80, ["A","B"][ir], fontsize=18)
    axs[0].set_xlabel('Fold Accuracy' if ir ==1 else "", fontsize = 14)
    axs[0].set_ylabel("Count" if ir==0 else "", fontsize = 14)

    s , sax = draw_stars_box(actual_dist, null_dist,
                   "wilcoxon", "roi", ylabel="Accuracy" if ir==0 else "", ax=axs[1], show=True,
                             ir = ir,
                             reverse_labels=False)
    # axs[0].text(0.25, 80, ["A","B"][ir], fontsize=38)
    # sax.text(0.25, 80, ["C","D"][ir], fontsize=38)
    if ir==0:
        sax.set_xlabel("", fontsize = 14)
        sax.yaxis.set_label_position("right")
        sax.yaxis.tick_right()

    actual_rank = [x for x in null_dist if x > actual_error]
    print(f"For {roi}: Total {len(null_dist)} random vec, rank of actual ({actual_error}) is {len(actual_rank)/len(null_dist)} ({len(actual_rank)}/{len(null_dist)})")
    ir+=1
# sns.set(font_scale=1)
# Out:
# roi : wilcoxon: z = 7723.5 , p = 9.026807530222338e-155
# For reward: Total 1000 random vec, rank of actual (0.7488333333333336) is 0.012 (12/1000)
# roi : wilcoxon: z = 48093.5 , p = 4.368299436562977e-108
# For vision: Total 1000 random vec, rank of actual (0.6422499999999987) is 0.085 (85/1000)
